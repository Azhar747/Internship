# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("E:\\flipRobo Projects\\customer_retention_dataset.csv")

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# So there are 269 rows and 71 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
sns.countplot(df["1Gender of respondent"])
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# So there are more female than male

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["2 How old are you? "])
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# So 31 to 40 years are more in this dataset when compared to other

# %%
3 Which city do you shop online from?
# Out:
# Object `from` not found.

# %%
df.rename(columns={df.columns[2]:"3_City"},inplace=True)
plt.figure(figsize=(15,7))
sns.countplot(df["3_City"])
# Out:
# <AxesSubplot:xlabel='3_City', ylabel='count'>

# %% [markdown]
# So most of the people who shop are from Delhi

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["5 Since How Long You are Shopping Online ?"])
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %% [markdown]
# So most of the people who are shopping onine are above 4 years

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["6 How many times you have made an online purchase in the past 1 year?"],hue="3_City",data=df)
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %% [markdown]
# So most of the  people are from Delhi  and most of the people have shopped less than 10 times

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["7 How do you access the internet while shopping on-line?"],hue="3_City",data=df)
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %% [markdown]
# So most of the people use mobile internet to shop online

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["7 How do you access the internet while shopping on-line?"])
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["8 Which device do you use to access the online shopping?"],hue="3_City",data=df)
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %% [markdown]
# So most of the peopole use Smartphone to do online shopping

# %%
df.columns[8]
# Out:
# '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '

# %%
df.rename(columns={df.columns[8]:"9_Screen Size"},inplace=True)

# %%
df.columns[8]
# Out:
# '9_Screen Size'

# %%
df.rename(columns={df.columns[9]:"10_Operating_System_of_device"},inplace=True)

# %%
df.rename(columns={df.columns[10]:"11_Browser_of_device"},inplace=True)

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["9_Screen Size"])
# Out:
# <AxesSubplot:xlabel='9_Screen Size', ylabel='count'>

# %% [markdown]
# So most of the people use other than size 4.7,5.5,5

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["10_Operating_System_of_device"])
# Out:
# <AxesSubplot:xlabel='10_Operating_System_of_device', ylabel='count'>

# %% [markdown]
# So most of the pople use Window/Windows Mobile

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["11_Browser_of_device"])
# Out:
# <AxesSubplot:xlabel='11_Browser_of_device', ylabel='count'>

# %% [markdown]
# So out all the browsers Google Chrome is most used browser

# %%
df.rename(columns={df.columns[11]:"12_Channel_Followed_To_Arrive_Favourite_Online_Store"},inplace=True)

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["12_Channel_Followed_To_Arrive_Favourite_Online_Store"])
# Out:
# <AxesSubplot:xlabel='12_Channel_Followed_To_Arrive_Favourite_Online_Store', ylabel='count'>

# %% [markdown]
# So in the above graph we can see that Search Engine is used to arrive on the online store

# %%
df.rename(columns={df.columns[12]:"13_After_first_visit_how_do_you_reach_the_online_retail_store?"},inplace=True)

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["13_After_first_visit_how_do_you_reach_the_online_retail_store?"])
# Out:
# <AxesSubplot:xlabel='13_After_first_visit_how_do_you_reach_the_online_retail_store?', ylabel='count'>

# %%
df.rename(columns={df.columns[13]:"14_How_much_time_do_you_explore_the_e_retail_store_before_making_a_purchase_decision?"},inplace=True)

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["14_How_much_time_do_you_explore_the_e_retail_store_before_making_a_purchase_decision?"])
# Out:
# <AxesSubplot:xlabel='14_How_much_time_do_you_explore_the_e_retail_store_before_making_a_purchase_decision?', ylabel='count'>

# %% [markdown]
# So people spend more than atlest 15 mins on online store before making the purchase decision

# %%
df.rename(columns={df.columns[14]:"15_What_is_your_preferred_payment_Option?"},inplace=True)

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["15_What_is_your_preferred_payment_Option?"])
# Out:
# <AxesSubplot:xlabel='15_What_is_your_preferred_payment_Option?', ylabel='count'>

# %% [markdown]
# So most of the people uses Credit and Debit card as the preferred payment option

# %%
df.rename(columns={df.columns[15]:"16_How_frequently_do_you_abandon_(selecting_an_items_and_leaving_without_making_payment)_your_shopping_cart?"},inplace=True)
plt.figure(figsize=(15,7))
sns.countplot(df["16_How_frequently_do_you_abandon_(selecting_an_items_and_leaving_without_making_payment)_your_shopping_cart?"])
# Out:
# <AxesSubplot:xlabel='16_How_frequently_do_you_abandon_(selecting_an_items_and_leaving_without_making_payment)_your_shopping_cart?', ylabel='count'>

# %% [markdown]
# So sometimes people after selecting the items leave it without making the payment

# %%
df.rename(columns={df.columns[16]:"17_Why_did_you_abandon_the_“Bag”,_“Shopping_Cart”?"},inplace=True)
plt.figure(figsize=(15,7))
sns.countplot(df["17_Why_did_you_abandon_the_“Bag”,_“Shopping_Cart”?"])
# Out:
# <AxesSubplot:xlabel='17_Why_did_you_abandon_the_“Bag”,_“Shopping_Cart”?', ylabel='count'>

# %% [markdown]
# So people abadan the Bag because the got the alternative offer

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["18 The content on the website must be easy to read and understand"])
# Out:
# <AxesSubplot:xlabel='18 The content on the website must be easy to read and understand', ylabel='count'>

# %% [markdown]
# So most the people agree that the website must be easy to read and understand

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["19 Information on similar product to the one highlighted  is important for product comparison"],hue="3_City",data=df)
# Out:
# <AxesSubplot:xlabel='19 Information on similar product to the one highlighted  is important for product comparison', ylabel='count'>

# %% [markdown]
# So most of the from delhi agree that Information on similar product to the one highlighted  is important for product comparison

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["20 Complete information on listed seller and product being offered is important for purchase decision."])
# Out:
# <AxesSubplot:xlabel='20 Complete information on listed seller and product being offered is important for purchase decision.', ylabel='count'>

# %% [markdown]
# So  most of the people agree that Complete information on listed seller and product being offered is important for purchase decision.

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["21 All relevant information on listed products must be stated clearly"])
# Out:
# <AxesSubplot:xlabel='21 All relevant information on listed products must be stated clearly', ylabel='count'>

# %% [markdown]
# So  most of the people agree that All relevant information on listed products must be stated clearly

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["22 Ease of navigation in website"])
# Out:
# <AxesSubplot:xlabel='22 Ease of navigation in website', ylabel='count'>

# %% [markdown]
# So  most of the people Stongly agree that Ease of navigation in website

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["23 Loading and processing speed"])
# Out:
# <AxesSubplot:xlabel='23 Loading and processing speed', ylabel='count'>

# %% [markdown]
# So  most of the people Stongly agree that Loading and processing speed

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["24 User friendly Interface of the website"])
# Out:
# <AxesSubplot:xlabel='24 User friendly Interface of the website', ylabel='count'>

# %% [markdown]
# So  most of the people Stongly that there shoul be User friendly Interface of the website

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["25 Convenient Payment methods"])
# Out:
# <AxesSubplot:xlabel='25 Convenient Payment methods', ylabel='count'>

# %% [markdown]
# So  most of the people Stongly agree that there should be Convenient Payment methods

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time"])
# Out:
# <AxesSubplot:xlabel='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that Trust that the online retail store will fulfill its part of the transaction at the stipulated time

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["27 Empathy (readiness to assist with queries) towards the customers"])
# Out:
# <AxesSubplot:xlabel='27 Empathy (readiness to assist with queries) towards the customers', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that Empathy (readiness to assist with queries) towards the customers

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["28 Being able to guarantee the privacy of the customer"])
# Out:
# <AxesSubplot:xlabel='28 Being able to guarantee the privacy of the customer', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that Being able to guarantee the privacy of the customer

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)"])
# Out:
# <AxesSubplot:xlabel='29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["30 Online shopping gives monetary benefit and discounts"])
# Out:
# <AxesSubplot:xlabel='30 Online shopping gives monetary benefit and discounts', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that Online shopping gives monetary benefit and discount

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["31 Enjoyment is derived from shopping online"])
# Out:
# <AxesSubplot:xlabel='31 Enjoyment is derived from shopping online', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that Enjoyment is derived from shopping online

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["32 Shopping online is convenient and flexible"])
# Out:
# <AxesSubplot:xlabel='32 Shopping online is convenient and flexible', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that Shopping online is convenient and flexible

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["33 Return and replacement policy of the e-tailer is important for purchase decision"])
# Out:
# <AxesSubplot:xlabel='33 Return and replacement policy of the e-tailer is important for purchase decision', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that Return and replacement policy of the e-tailer is important for purchase decision

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["35 Displaying quality Information on the website improves satisfaction of customers"])
# Out:
# <AxesSubplot:xlabel='35 Displaying quality Information on the website improves satisfaction of customers', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that Displaying quality Information on the website improves satisfaction of customers

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["34 Gaining access to loyalty programs is a benefit of shopping online"])
# Out:
# <AxesSubplot:xlabel='34 Gaining access to loyalty programs is a benefit of shopping online', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that  Gaining access to loyalty programs is a benefit of shopping online

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["36 User derive satisfaction while shopping on a good quality website or application"])
# Out:
# <AxesSubplot:xlabel='36 User derive satisfaction while shopping on a good quality website or application', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that User derive satisfaction while shopping on a good quality website or application"

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["37 Net Benefit derived from shopping online can lead to users satisfaction"])
# Out:
# <AxesSubplot:xlabel='37 Net Benefit derived from shopping online can lead to users satisfaction', ylabel='count'>

# %%
So most of the people Stongly agree that

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["38 User satisfaction cannot exist without trust"])
# Out:
# <AxesSubplot:xlabel='38 User satisfaction cannot exist without trust', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that User satisfaction cannot exist without trust

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["39 Offering a wide variety of listed product in several category"])
# Out:
# <AxesSubplot:xlabel='39 Offering a wide variety of listed product in several category', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that Offering a wide variety of listed product in several category

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["40 Provision of complete and relevant product information"])
# Out:
# <AxesSubplot:xlabel='40 Provision of complete and relevant product information', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that  Provision of complete and relevant product information

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["41 Monetary savings"])
# Out:
# <AxesSubplot:xlabel='41 Monetary savings', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that Monetary savings is the good thing

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["42 The Convenience of patronizing the online retailer"])
# Out:
# <AxesSubplot:xlabel='42 The Convenience of patronizing the online retailer', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that The Convenience of patronizing the online retailer

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["43 Shopping on the website gives you the sense of adventure"])
# Out:
# <AxesSubplot:xlabel='43 Shopping on the website gives you the sense of adventure', ylabel='count'>

# %%
So most of the people agree that Shopping on the website gives you the sense of adventure

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["44 Shopping on your preferred e-tailer enhances your social status"])
# Out:
# <AxesSubplot:xlabel='44 Shopping on your preferred e-tailer enhances your social status', ylabel='count'>

# %% [markdown]
# So very less number of people agree that  Shopping on your preferred e-tailer enhances your social status

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["45 You feel gratification shopping on your favorite e-tailer"])
# Out:
# <AxesSubplot:xlabel='45 You feel gratification shopping on your favorite e-tailer', ylabel='count'>

# %% [markdown]
# So very less number of people agree that You feel gratification shopping on your favorite e-taile

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["46 Shopping on the website helps you fulfill certain roles"])
# Out:
# <AxesSubplot:xlabel='46 Shopping on the website helps you fulfill certain roles', ylabel='count'>

# %% [markdown]
# So most of the people agree that Shopping on the website helps you fulfill certain roles

# %%
plt.figure(figsize=(15,7))
sns.countplot(df["47 Getting value for money spent"])
# Out:
# <AxesSubplot:xlabel='47 Getting value for money spent', ylabel='count'>

# %% [markdown]
# So most of the people Stongly agree that  Getting value for money spent

# %% [markdown]
# So most of the people agre that they should get the value of moeny spent

# %%
df.rename(columns={df.columns[47]:"From_the_following,_tick_any_(or_all)_of_the_online_retailers_you_have_shopped_from"},inplace=True)

# %%
plt.figure(figsize=(20,7))
plt.xticks(rotation=90)
sns.countplot(df["From_the_following,_tick_any_(or_all)_of_the_online_retailers_you_have_shopped_from"])
# Out:
# <AxesSubplot:xlabel='From_the_following,_tick_any_(or_all)_of_the_online_retailers_you_have_shopped_from', ylabel='count'>

# %%
df["From_the_following,_tick_any_(or_all)_of_the_online_retailers_you_have_shopped_from"].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From_the_following,_tick_any_(or_all)_of_the_online_retailers_you_have_shopped_from, dtype: int64

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=85)
sns.countplot(df["Easy to use website or application"])
# Out:
# <AxesSubplot:xlabel='Easy to use website or application', ylabel='count'>

# %% [markdown]
# So most people marked Amazon,flipkart,paytm,snapdeal etc are all easy to use

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Visual appealing web-page layout"])
# Out:
# <AxesSubplot:xlabel='Visual appealing web-page layout', ylabel='count'>

# %% [markdown]
# So most people marked Amazon.in, Flipkart.com Visual appealing web-page layout

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Wild variety of product on offer"])
# Out:
# <AxesSubplot:xlabel='Wild variety of product on offer', ylabel='count'>

# %% [markdown]
# So most people marked Amazon.in, Flipkart.com has Wild variety of product on offer

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Fast loading website speed of website and application"])
# Out:
# <AxesSubplot:xlabel='Fast loading website speed of website and application', ylabel='count'>

# %% [markdown]
# So most people marked Amazon.in has Fast loading website speed of website and application

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Reliability of the website or application"])
# Out:
# <AxesSubplot:xlabel='Reliability of the website or application', ylabel='count'>

# %% [markdown]
# So most people marked Amazon.in has Reliability of the website or application

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Quickness to complete purchase"])
# Out:
# <AxesSubplot:xlabel='Quickness to complete purchase', ylabel='count'>

# %% [markdown]
# So most people marked Amazon.in is quick to complete purchase

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Availability of several payment options"])
# Out:
# <AxesSubplot:xlabel='Availability of several payment options', ylabel='count'>

# %% [markdown]
# So most people marked Amazon.in, Flipkart.com has facility several payment options

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Speedy order delivery "])
# Out:
# <AxesSubplot:xlabel='Speedy order delivery ', ylabel='count'>

# %% [markdown]
# So most people marked Amazon.in has Speedy order delivery

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Privacy of customers’ information"])
# Out:
# <AxesSubplot:xlabel='Privacy of customers’ information', ylabel='count'>

# %% [markdown]
# So most people marked Amazon.in has Privacy of customers’ information

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Security of customer financial information"])
# Out:
# <AxesSubplot:xlabel='Security of customer financial information', ylabel='count'>

# %% [markdown]
# So most people marked Amazon.in has Security of customer financial information

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Perceived Trustworthiness"])
# Out:
# <AxesSubplot:xlabel='Perceived Trustworthiness', ylabel='count'>

# %% [markdown]
# So most people marked Amazon.in has Perceived Trustworthiness

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Presence of online assistance through multi-channel"])
# Out:
# <AxesSubplot:xlabel='Presence of online assistance through multi-channel', ylabel='count'>

# %% [markdown]
#  So most people marked Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com   Presence of online assistance through multi-channel

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Longer time to get logged in (promotion, sales period)"])
# Out:
# <AxesSubplot:xlabel='Longer time to get logged in (promotion, sales period)', ylabel='count'>

# %% [markdown]
# So most people marked Amazon.in has Longer time to get logged in (promotion, sales period)

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Longer time in displaying graphics and photos (promotion, sales period)"])
# Out:
# <AxesSubplot:xlabel='Longer time in displaying graphics and photos (promotion, sales period)', ylabel='count'>

# %% [markdown]
# So most people marked Amazon.in,Flipkart.com  Longer time in displaying graphics and photos (promotion, sales period)

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Late declaration of price (promotion, sales period)"])
# Out:
# <AxesSubplot:xlabel='Late declaration of price (promotion, sales period)', ylabel='count'>

# %% [markdown]
# So most people marked  Myntra.com has Late declaration of price (promotion, sales period)

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Longer page loading time (promotion, sales period)"])
# Out:
# <AxesSubplot:xlabel='Longer page loading time (promotion, sales period)', ylabel='count'>

# %% [markdown]
# So most people marked Myntra.com,Paytm.com has Longer page loading time (promotion, sales period)

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Limited mode of payment on most products (promotion, sales period)"])
# Out:
# <AxesSubplot:xlabel='Limited mode of payment on most products (promotion, sales period)', ylabel='count'>

# %% [markdown]
# So most people marked Snapdeal has Limited mode of payment on most products (promotion, sales period

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Longer delivery period"])
# Out:
# <AxesSubplot:xlabel='Longer delivery period', ylabel='count'>

# %% [markdown]
# So most people marked Paytm.com has Longer delivery period

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Change in website/Application design"])
# Out:
# <AxesSubplot:xlabel='Change in website/Application design', ylabel='count'>

# %% [markdown]
# So most people marked Azmzon.in has  Change in website/Application design

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Frequent disruption when moving from one page to another"])
# Out:
# <AxesSubplot:xlabel='Frequent disruption when moving from one page to another', ylabel='count'>

# %% [markdown]
# So most people marked Azamzon.in,Myntra hasFrequent disruption when moving from one page to another

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Website is as efficient as before"])
# Out:
# <AxesSubplot:xlabel='Website is as efficient as before', ylabel='count'>

# %% [markdown]
# So most people marked Azamzon.in Website is as efficient as before

# %%
plt.figure(figsize=(15,7))
plt.xticks(rotation=90)
sns.countplot(df["Which of the Indian online retailer would you recommend to a friend?"])
# Out:
# <AxesSubplot:xlabel='Which of the Indian online retailer would you recommend to a friend?', ylabel='count'>

# %% [markdown]
# So most of people will recommend Amazon.in to the friend for online shopping

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ', '3_City',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9_Screen Size', '10_Operating_System_of_device',
#        '11_Browser_of_device',
#        '12_Channel_Followed_To_Arrive_Favourite_Online_Store',
#        '13_After_first_visit_how_do_you_reach_the_online_retail_store?',
#        '14_How_much_time_do_you_explore_the_e_retail_store_before_making_a_purchase_decision?',
#        '15_What_is_your_preferred_payment_Option?',
#        '16_How_frequently_do_you_abandon_(selecting_an_items_and_leaving_without_making_payment)_your_shopping_cart?',
#        '17_Why_did_you_abandon_the_“Bag”,_“Shopping_Cart”?',
# ...

# %% [markdown]
# Conclusion:
#
#
# A Good website E-Commerce website should have the following qualities for customer retension
#
# 1.	Easy to use website or application',
# 2.	'Visual appealing web-page layout',
# 3.	 'Wild variety of product on offer',
# 4.	'Complete, relevant description information of products'
# 5.	'Fast loading website speed of website and application'
# 6.	Reliability of the website or application',
# 7.	Quickness to complete purchase',
# 8.	Availability of several payment options',
# 9.	 'Speedy order delivery ',
# 10.	Privacy of customers’ information',
# 11.	Security of customer financial information',
# 12.	 'Perceived Trustworthiness',
# 13.	Presence of online assistance through multi-channel',

# %% [markdown]
# A Good website E-Commerce website should not have the following:-
#
# 1.	Longer time to get logged in (promotion, sales period)',
# 2.	Longer time in displaying graphics and photos (promotion, sales period)',
# 3.	Late declaration of price (promotion, sales period)',
# 4.	Longer page loading time (promotion, sales period)',
# 5.	Limited mode of payment on most products (promotion, sales period)',
# 6.	Longer delivery period', '
# 7.	Change in website/Application design',
